# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("../dataset/Cleaned_Superstore.csv")

# %%
print(df.head())
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  2016-11-08  2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156  2016-11-08  2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688  2016-06-12  2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966  2015-10-11  2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966  2015-10-11  2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   str
#  2   Order Date     9994 non-null   str
#  3   Ship Date      9994 non-null   str
#  4   Ship Mode      9994 non-null   str
#  5   Customer ID    9994 non-null   str
#  6   Customer Name  9994 non-null   str
#  7   Segment        9994 non-null   str
#  8   Country        9994 non-null   str
#  9   City           9994 non-null   str
#  10  State          9994 non-null   str
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   str
#  13  Product ID     9994 non-null   str
#  14  Category       9994 non-null   str
#  15  Sub-Category   9994 non-null   str
#  16  Product Name   9994 non-null   str
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
# ...

# %%
print(df.isnull().sum())
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
df.to_csv("../outputs/processed_data.csv", index=False)

# %%
# Calculate KPIs

total_sales = df["Sales"].sum()
total_profit = df["Profit"].sum()
total_orders = df["Order ID"].nunique()
total_customers = df["Customer ID"].nunique()
average_sales = df["Sales"].mean()

print("----- KPI Summary -----")
print(f"Total Sales: {total_sales:.2f}")
print(f"Total Profit: {total_profit:.2f}")
print(f"Total Orders: {total_orders}")
print(f"Total Customers: {total_customers}")
print(f"Average Sales: {average_sales:.2f}")
# Out:
# ----- KPI Summary -----
# Total Sales: 2297200.86
# Total Profit: 286397.02
# Total Orders: 5009
# Total Customers: 793
# Average Sales: 229.86

# %%
kpi_summary = pd.DataFrame({
    "Metric": [
        "Total Sales",
        "Total Profit",
        "Total Orders",
        "Total Customers",
        "Average Sales"
    ],
    "Value": [
        total_sales,
        total_profit,
        total_orders,
        total_customers,
        average_sales
    ]
})

kpi_summary.to_csv("../outputs/kpi_summary.csv", index=False)

# %%
# Export Processed Data and KPI Summary to Excel

with pd.ExcelWriter("../outputs/final_report.xlsx") as writer:
    df.to_excel(writer, sheet_name="Processed Data", index=False)
    kpi_summary.to_excel(writer, sheet_name="KPI Summary", index=False)

print("Excel report exported successfully!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 3
#       1 # Export Processed Data and KPI Summary to Excel
#       2
# ----> 3 with pd.ExcelWriter("../outputs/final_report.xlsx") as writer:
#       4     df.to_excel(writer, sheet_name="Processed Data", index=False)
#       5     kpi_summary.to_excel(writer, sheet_name="KPI Summary", index=False)
#       6
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\io\excel\_openpyxl.py:58, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      45 def __init__(  # pyright: ignore[reportInconsistentConstructor]
#      46     self,
#      47     path: FilePath | WriteExcelBuffer | ExcelWriter,
#    (...)     56 ) -> None:
#      57     # Use the openpyxl module as the Excel writer.
# ...

# %%
# !pip install openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# ...

# %%
with pd.ExcelWriter("../outputs/final_report.xlsx") as writer:
    df.to_excel(writer, sheet_name="Processed Data", index=False)
    kpi_summary.to_excel(writer, sheet_name="KPI Summary", index=False)

print("Excel report exported successfully!")
# Out:
# Excel report exported successfully!
